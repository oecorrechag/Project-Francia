# %% [markdown]
# https://stackoverflow.com/questions/56040817/python-fuzzy-matching-strings-in-list-performance

# %%
from fuzzywuzzy import fuzz
import pandas as pd
import numpy as np

pd.set_option('display.float_format', lambda x: '%.2f' % x)
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %%
dataframecolumn = pd.DataFrame(['Bogota','Medellin','Purisima','Purificacion','Uramita','Urumita'])
dataframecolumn.columns = ['Match']
dataframecolumn['Key'] = 1
dataframecolumn
# Out:
#           Match  Key
# 0        Bogota    1
# 1      Medellin    1
# 2      Purisima    1
# 3  Purificacion    1
# 4       Uramita    1
# 5       Urumita    1

# %%
compare = pd.DataFrame(['Bogota', 'bogota', 'Bogota DC', 'bogota dc', 'medellin', 'Medellin', 'Medellín', 'purisiima','prurificacion','urumita'])
compare.columns = ['compare']
compare['Key'] = 1
compare
# Out:
#          compare  Key
# 0         Bogota    1
# 1         bogota    1
# 2      Bogota DC    1
# 3      bogota dc    1
# 4       medellin    1
# 5       Medellin    1
# 6       Medellín    1
# 7      purisiima    1
# 8  prurificacion    1
# 9        urumita    1

# %%
x = np.arange(len(compare))

# %%
compare['compare2'] = compare['compare'].str.capitalize()
compare['id'] = x
compare
# Out:
#          compare  Key       compare2  id
# 0         Bogota    1         Bogota   0
# 1         bogota    1         Bogota   1
# 2      Bogota DC    1      Bogota dc   2
# 3      bogota dc    1      Bogota dc   3
# 4       medellin    1       Medellin   4
# 5       Medellin    1       Medellin   5
# 6       Medellín    1       Medellín   6
# 7      purisiima    1      Purisiima   7
# 8  prurificacion    1  Prurificacion   8
# 9        urumita    1        Urumita   9

# %%
combined_dataframe = dataframecolumn.merge(compare,on="Key",how="left")
# combined_dataframe = combined_dataframe[~(combined_dataframe.Match==combined_dataframe.compare)]
combined_dataframe
# Out:
#            Match  Key        compare       compare2  id
# 0         Bogota    1         Bogota         Bogota   0
# 1         Bogota    1         bogota         Bogota   1
# 2         Bogota    1      Bogota DC      Bogota dc   2
# 3         Bogota    1      bogota dc      Bogota dc   3
# 4         Bogota    1       medellin       Medellin   4
# 5         Bogota    1       Medellin       Medellin   5
# 6         Bogota    1       Medellín       Medellín   6
# 7         Bogota    1      purisiima      Purisiima   7
# 8         Bogota    1  prurificacion  Prurificacion   8
# 9         Bogota    1        urumita        Urumita   9
# 10      Medellin    1         Bogota         Bogota   0
# 11      Medellin    1         bogota         Bogota   1
# 12      Medellin    1      Bogota DC      Bogota dc   2
# 13      Medellin    1      bogota dc      Bogota dc   3
# 14      Medellin    1       medellin       Medellin   4
# 15      Medellin    1       Medellin       Medellin   5
# 16      Medellin    1       Medellín       Medellín   6
# 17      Medellin    1      purisiima      Purisiima   7
# 18      Medellin    1  prurificacion  Prurificacion   8
# 19      Medellin    1        urumita        Urumita   9
# 20      Purisima    1         Bogota         Bogota   0
# 21      Purisima    1         bogota         Bogota   1
# 22      Purisima    1      Bogota DC      Bogota dc   2
# 23      Purisima    1      bogota dc      Bogota dc   3
# 24      Purisima    1       medellin       Medellin   4
# 25      Purisima    1       Medellin       Medellin   5
# 26      Purisima    1       Medellín       Medellín   6
# 27      Purisima    1      purisiima      Purisiima   7
# 28      Purisima    1  prurificacion  Prurificacion   8
# 29      Purisima    1        urumita        Urumita   9
# 30  Purificacion    1         Bogota         Bogota   0
# 31  Purificacion    1         bogota         Bogota   1
# 32  Purificacion    1      Bogota DC      Bogota dc   2
# 33  Purificacion    1      bogota dc      Bogota dc   3
# 34  Purificacion    1       medellin       Medellin   4
# 35  Purificacion    1       Medellin       Medellin   5
# 36  Purificacion    1       Medellín       Medellín   6
# 37  Purificacion    1      purisiima      Purisiima   7
# 38  Purificacion    1  prurificacion  Prurificacion   8
# 39  Purificacion    1        urumita        Urumita   9
# 40       Uramita    1         Bogota         Bogota   0
# 41       Uramita    1         bogota         Bogota   1
# 42       Uramita    1      Bogota DC      Bogota dc   2
# 43       Uramita    1      bogota dc      Bogota dc   3
# 44       Uramita    1       medellin       Medellin   4
# 45       Uramita    1       Medellin       Medellin   5
# 46       Uramita    1       Medellín       Medellín   6
# 47       Uramita    1      purisiima      Purisiima   7
# 48       Uramita    1  prurificacion  Prurificacion   8
# 49       Uramita    1        urumita        Urumita   9
# 50       Urumita    1         Bogota         Bogota   0
# 51       Urumita    1         bogota         Bogota   1
# 52       Urumita    1      Bogota DC      Bogota dc   2
# 53       Urumita    1      bogota dc      Bogota dc   3
# 54       Urumita    1       medellin       Medellin   4
# 55       Urumita    1       Medellin       Medellin   5
# 56       Urumita    1       Medellín       Medellín   6
# 57       Urumita    1      purisiima      Purisiima   7
# 58       Urumita    1  prurificacion  Prurificacion   8
# 59       Urumita    1        urumita        Urumita   9

# %%
def partial_match(x,y):
    return(fuzz.ratio(x,y))
partial_match_vector = np.vectorize(partial_match)

# %%
combined_dataframe['score'] = partial_match_vector(combined_dataframe['Match'], combined_dataframe['compare2'])
combined_dataframe
# Out:
#            Match  Key        compare       compare2  id  score
# 0         Bogota    1         Bogota         Bogota   0    100
# 1         Bogota    1         bogota         Bogota   1    100
# 2         Bogota    1      Bogota DC      Bogota dc   2     80
# 3         Bogota    1      bogota dc      Bogota dc   3     80
# 4         Bogota    1       medellin       Medellin   4      0
# 5         Bogota    1       Medellin       Medellin   5      0
# 6         Bogota    1       Medellín       Medellín   6      0
# 7         Bogota    1      purisiima      Purisiima   7     13
# 8         Bogota    1  prurificacion  Prurificacion   8     11
# 9         Bogota    1        urumita        Urumita   9     31
# 10      Medellin    1         Bogota         Bogota   0      0
# 11      Medellin    1         bogota         Bogota   1      0
# 12      Medellin    1      Bogota DC      Bogota dc   2     12
# 13      Medellin    1      bogota dc      Bogota dc   3     12
# 14      Medellin    1       medellin       Medellin   4    100
# 15      Medellin    1       Medellin       Medellin   5    100
# 16      Medellin    1       Medellín       Medellín   6     88
# 17      Medellin    1      purisiima      Purisiima   7     12
# 18      Medellin    1  prurificacion  Prurificacion   8     19
# 19      Medellin    1        urumita        Urumita   9     13
# 20      Purisima    1         Bogota         Bogota   0     14
# 21      Purisima    1         bogota         Bogota   1     14
# 22      Purisima    1      Bogota DC      Bogota dc   2     12
# 23      Purisima    1      bogota dc      Bogota dc   3     12
# 24      Purisima    1       medellin       Medellin   4     12
# 25      Purisima    1       Medellin       Medellin   5     12
# 26      Purisima    1       Medellín       Medellín   6      0
# 27      Purisima    1      purisiima      Purisiima   7     94
# 28      Purisima    1  prurificacion  Prurificacion   8     57
# 29      Purisima    1        urumita        Urumita   9     40
# 30  Purificacion    1         Bogota         Bogota   0     11
# 31  Purificacion    1         bogota         Bogota   1     11
# 32  Purificacion    1      Bogota DC      Bogota dc   2     10
# 33  Purificacion    1      bogota dc      Bogota dc   3     10
# 34  Purificacion    1       medellin       Medellin   4     20
# 35  Purificacion    1       Medellin       Medellin   5     20
# 36  Purificacion    1       Medellín       Medellín   6     10
# 37  Purificacion    1      purisiima      Purisiima   7     57
# 38  Purificacion    1  prurificacion  Prurificacion   8     96
# 39  Purificacion    1        urumita        Urumita   9     32
# 40       Uramita    1         Bogota         Bogota   0     31
# 41       Uramita    1         bogota         Bogota   1     31
# 42       Uramita    1      Bogota DC      Bogota dc   2     25
# 43       Uramita    1      bogota dc      Bogota dc   3     25
# 44       Uramita    1       medellin       Medellin   4     13
# 45       Uramita    1       Medellin       Medellin   5     13
# 46       Uramita    1       Medellín       Medellín   6      0
# 47       Uramita    1      purisiima      Purisiima   7     25
# 48       Uramita    1  prurificacion  Prurificacion   8     30
# 49       Uramita    1        urumita        Urumita   9     86
# 50       Urumita    1         Bogota         Bogota   0     31
# 51       Urumita    1         bogota         Bogota   1     31
# 52       Urumita    1      Bogota DC      Bogota dc   2     25
# 53       Urumita    1      bogota dc      Bogota dc   3     25
# 54       Urumita    1       medellin       Medellin   4     13
# 55       Urumita    1       Medellin       Medellin   5     13
# 56       Urumita    1       Medellín       Medellín   6      0
# 57       Urumita    1      purisiima      Purisiima   7     38
# 58       Urumita    1  prurificacion  Prurificacion   8     40
# 59       Urumita    1        urumita        Urumita   9    100

# %%
combined_dataframe = combined_dataframe[combined_dataframe.score >= 80]
combined_dataframe
# Out:
#            Match  Key        compare       compare2  id  score
# 0         Bogota    1         Bogota         Bogota   0    100
# 1         Bogota    1         bogota         Bogota   1    100
# 2         Bogota    1      Bogota DC      Bogota dc   2     80
# 3         Bogota    1      bogota dc      Bogota dc   3     80
# 14      Medellin    1       medellin       Medellin   4    100
# 15      Medellin    1       Medellin       Medellin   5    100
# 16      Medellin    1       Medellín       Medellín   6     88
# 27      Purisima    1      purisiima      Purisiima   7     94
# 38  Purificacion    1  prurificacion  Prurificacion   8     96
# 49       Uramita    1        urumita        Urumita   9     86
# 59       Urumita    1        urumita        Urumita   9    100
